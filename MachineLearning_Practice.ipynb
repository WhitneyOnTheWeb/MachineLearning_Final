# %% [markdown]
# ## Get Data Set

# %%
# %run tools/startup.py
# Out:
# checking for nltk
# checking for numpy
# checking for scipy
# checking for sklearn
# downloading the Enron dataset (this may take a while)
# to check on progress, you can cd up one level, then execute <ls -lthr>
# Enron dataset should be last item on the list, along with its current size
# download will complete at about 423 MB
# download complete!
# unzipping Enron dataset (this may take a while)
# you're ready to go!

# %% [markdown]
# ## Naive Bayes
# #### Test Example Files

# %%
#%matplotlib inline
#%run studentMain.py
# Out:
# 0.884

# %% [markdown]
# #### NB Mini Project
#
# Convert data file to UNIX for parsing with pickle

# %%
# %run tools/dos2unix.py

#References:

# Update for Python 3: 
#     https://github.com/udacity/ud120-projects/pull/71/commits/e29fdebe40c791820f361f13feb6cbdbc3bf6de2
# Convert data for Py3 pickle: 
#    https://github.com/udacity/ud120-projects/issues/46
# Out:
# Done. Saved 35156 bytes.

# %%
# %run naive_bayes/nb_author_id.py
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# training time: 1.07 s
# prediction time: 0.163 s
# 0.973265073948

# %% [markdown]
# ## SVM
#
# Support Vector Machine

# %%
#%matplotlib inline
#%run studentMain.py
# Out:
# 0.924

# %%
# Large Training Set - Linear
#%run svm/svm_author_id.py

# %% [markdown]
# * no. of Chris training emails: 7936
# * no. of Sara training emails: 7884
# * training time: 121.803 s
# * prediction time: 12.74 s
# * 0.984072810011

# %%
# Small Training Set - Linear

#features_train = features_train[:int(len(features_train)/100)] 
#labels_train = labels_train[:int(len(labels_train)/100)] 

#%run svm/svm_author_id.py

# %% [markdown]
# * no. of Chris training emails: 7936
# * no. of Sara training emails: 7884
# * training time: 0.066 s
# * prediction time: 0.702 s
# * 0.884527872582

# %%
# Small Training Set - RBF
#%run svm/svm_author_id.py

# %% [markdown]
# * no. of Chris training emails: 7936
# * no. of Sara training emails: 7884
# * training time: 0.07 s
# * prediction time: 0.634 s
# * 0.892491467577

# %%
# Large Training Set - RBF
#%run svm/svm_author_id.py

# %% [markdown]
# * no. of Chris training emails: 7936
# * no. of Sara training emails: 7884
# * training time: 80.534 s
# * prediction time: 8.74 s
# * 0.990898748578

# %%
# Small Training Set - RBF, Predictions for 10, 26, 50
#%run svm/svm_author_id.py

# %% [markdown]
# * no. of Chris training emails: 7936
# * no. of Sara training emails: 7884
# * training time: 79.661 s
# * prediction time: 8.066 s
# * pred[10]:  1
# * pred[26]:  0
# * pred[50]:  1
# * Training Emails:  1758
# * Predicted Chris Emails:  877
# * 0.990898748578

# %% [markdown]
# ## Decision Trees

# %%
# Generate picture of decision boudary for Decision Trees
#%matplotlib inline
#%run studentMain.py
# Out:
# 0.912

# %%
# min_samples_split = 40
# %run decision_tree/dt_author_id.py
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# training time: 4.226 s
# prediction time: 0.002 s
# pred[10]:  1
# pred[26]:  0
# pred[50]:  1
# Training Emails:  1758
# Predicted Chris Emails:  887
# 0.967007963595
# 379

# %% [markdown]
# ## Choose Your Own Algorithm
# #### AdaBoost

# %%
# %matplotlib inline
# %run choose_your_own/your_algorithm.py
# Out:
# training time: 0.081 s
# prediction time: 0.005 s
# pred[10]:  1.0
# pred[45]:  1.0
# pred[50]:  1.0
# Total Features:  250
# Type 1:  165
# Type 0:  85
# 0.924

# %% [markdown]
# ## Enron Mini Project

# %%
#Convert final_project_dataset.pkl to Unix readable format
# %run tools/dos2unix.py
# Out:
# Done. Saved 6705 bytes.

# %%
# %matplotlib inline
# %run datasets_questions/explore_enron_data.py
# Out:
# {'salary': 1111258, 'to_messages': 3627, 'deferral_payments': 'NaN', 'total_payments': 8682716, 'loan_advances': 'NaN', 'bonus': 5600000, 'email_address': 'jeff.skilling@enron.com', 'restricted_stock_deferred': 'NaN', 'deferred_income': 'NaN', 'total_stock_value': 26093672, 'expenses': 29336, 'from_poi_to_this_person': 88, 'exercised_stock_options': 19250000, 'from_messages': 108, 'other': 22122, 'from_this_person_to_poi': 30, 'poi': True, 'long_term_incentive': 1920000, 'shared_receipt_with_poi': 2042, 'restricted_stock': 6843672, 'director_fees': 'NaN'}
# 146
# 21
# 18
# 90
# 35
# 1095040
# 11
# 19250000
# Max Executive Salary: LAY KENNETH L ,  103559793
# 95
# 0

# %% [markdown]
# ## Regression

# %%
#Training Data - bonus vs salary

# %matplotlib inline
# %run regression/finance_regression.py
# Out:
# Slope:  [ 5.44814029]
# Intercept:  -102360.543294
# R^2 Score:  0.0455091926995

# %%
#Fit test data R^2 score on training data (bonus vs salary)
#Slope 2 is data without outliers

# %matplotlib inline
# %run regression/finance_regression.py
# Out:
# Slope:  [ 5.44814029]
# Intercept:  -102360.543294
# R^2 Score:  -1.48499241737
# Slope 2:  [ 2.27410114]

# %%
#R^2 of long_erm_incentive vs bonus

# %matplotlib inline
# %run regression/finance_regression.py
# Out:
# Slope:  [ 1.19214699]
# Intercept:  554478.756215
# R^2 Score:  -0.59271289995
# Slope 2:  [ 0.40364065]

# %% [markdown]
# ## Outliers

# %%
#Training data
# %matplotlib inline
# %run outliers/outlier_removal_regression.py
# Out:
# Slope:  [[ 5.07793064]]
# Intercept:  [ 25.21002155]
# R^2 Score:  0.489872596175
# outlierCleaner() is returning an empty list, no refitting to be done

# %%
#Test data
# %matplotlib inline
# %run outliers/outlier_removal_regression.py
# Out:
# Slope:  [[ 5.07793064]]
# Intercept:  [ 25.21002155]
# R^2 Score:  0.878262470366
# Slope (No Outliers):  [[ 6.36859481]]
# Intercept (No Outliers):  [-6.91861069]
# R^2 Score (No Outliers):  0.983189455396

# %%
#Test data
# %matplotlib inline
# %run outliers/enron_outliers.py
# Out:
# Max Salary:  SKILLING JEFFREY K
# LAY KENNETH L bonus:  7000000 salary:  1072321
# SKILLING JEFFREY K bonus:  5600000 salary:  1111258

# %% [markdown]
# ## Clustering

# %%
#2 features, 2 clusters
# %matplotlib inline
# %run k_means/k_means_cluster.py
# Out:
# training time: 0.011 s
# prediction time: 0.001 s
# 0.879032258065

# %%
# 3 features, 2 clusters, exclude NaN
# %matplotlib inline
# %run k_means/k_means_cluster.py
# Out:
# Max stock:  LAY KENNETH L 34348384
# Min stock:  BELFER ROBERT 3285
# Max salary:  SKILLING JEFFREY K 1111258
# Min salary:  BANNANTINE JAMES M 477
# training time: 0.01 s
# prediction time: 0.001 s
# 0.140845070423

# %% [markdown]
# ## Feature Scaling

# %%
# 2 features, 2 clusters, exclude NaN w/ rescaler
# %matplotlib inline
# %run k_means/k_means_cluster.py
# Out:
# Max stock:  LAY KENNETH L 34348384
# Min stock:  BELFER ROBERT 3285
# Max salary:  SKILLING JEFFREY K 1111258
# Min salary:  BANNANTINE JAMES M 477
# Scaled stock:  [[ 0.        ]
#  [ 0.02902059]
#  [ 1.        ]]
# Scaled salary:  [[ 0.        ]
#  [ 0.17962407]
#  [ 1.        ]]
# training time: 0.011 s
# prediction time: 0.001 s
# 0.87323943662

# %% [markdown]
# ## Text Learning

# %%
import nltk
#nltk.download('all', halt_on_error=False)
from nltk.corpus import stopwords

# %%
from nltk.corpus import stopwords

sw = stopwords.words('english')
print(sw[0:10])
print(len(sw))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your']
# 153

# %%
# %run tools/parse_out_email_text.py
# Out:
# hi everyon if you can read this messag your proper use parseouttext pleas proceed to the next part of the project

# %%
# %run text_learning/vectorize_text.py
# Out:
# tjonesnsf stephani and sam need nymex calendar
# emails processed
# 38757
# stephaniethank

# %% [markdown]
# ## Feature Selection

# %%
#%run feature_selection/studentMain.py
# %run feature_selection/find_signature.py
# Out:
# training time: 0.112 s
# prediction time: 0.201 s
# 0.816268486917
# 150
# [[0.21629799316658735, 18849], [0.420772351026551, 21323]]
# fax houectect

# %% [markdown]
# ## PCA
# Principal Component Analysis

# %%
# %run pca/eigenfaces.py
# Out:
# ...
# Faces recognition example using eigenfaces and SVMs
# ...
#
# The dataset used in this example is a preprocessed excerpt of the
# "Labeled Faces in the Wild", aka LFW_:
#
#   http://vis-www.cs.umass.edu/lfw/lfw-funneled.tgz (233MB)
#
#   .. _LFW: http://vis-www.cs.umass.edu/lfw/
#
#   original source: http://scikit-learn.org/stable/auto_examples/applications/face_recognition.html
# C:\Users\dooki\Anaconda3\envs\py3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# ...

# %% [markdown]
# ## Validation / Evaluation Metrics

# %%
# %run validation/validate_poi.py
# Out:
# training time: 0.001 s
# prediction time: 0.0 s
# Accuracy: 0.724137931034
# Precision: 0.0
# Recall: 0.0
# # POIs: 4
# # Test Features 29
# TPs: 0
# 0.75 0.666666666667
